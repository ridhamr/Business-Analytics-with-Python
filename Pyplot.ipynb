# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6]

# %%
y=[1,4,9,16,25,36]

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y,'o')

# %%
plt.plot(x,y,'ro')

# %%
plt.plot(x,y,'*')

# %%
plt.plot(x,y,'r*')

# %%
plt.plot(x,y,'--')

# %%
plt.plot(x,y,'-*')

# %%
x=[1,2,3,4,5,6]

# %%
y=[1,4,9,16,25,36]

# %%
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('Sales V/S Profit')
plt.plot(x,y,'-*')

# %%
x=['Dhoni','Kohli','Yuvraj']
y=[100,23,44]
plt.bar(x,y,color='red')
# Out:
# <BarContainer object of 3 artists>
